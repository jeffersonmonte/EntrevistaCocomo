-- %% [markdown]
-- # [dbo].[ConversoesTamanho]

-- %%
USE [CocomoBase]
GO

-- %%
/****** Object:  Table [dbo].[ConversoesTamanho]    Script Date: 11/08/2025 20:06:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConversoesTamanho](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TipoEntrada] [nvarchar](20) NOT NULL,
	[Contexto] [nvarchar](100) NOT NULL,
	[FatorConversao] [decimal](8, 4) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EffortMultipliers]

-- %%
/****** Object:  Table [dbo].[EffortMultipliers]    Script Date: 11/08/2025 20:06:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EffortMultipliers](
	[Id] [uniqueidentifier] NOT NULL,
	[EntrevistaId] [uniqueidentifier] NOT NULL,
	[Nome] [nvarchar](50) NOT NULL,
	[Nivel] [nvarchar](50) NOT NULL,
	[Valor] [decimal](5, 3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Entrevistas]

-- %%
/****** Object:  Table [dbo].[Entrevistas]    Script Date: 11/08/2025 20:06:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Entrevistas](
	[Id] [uniqueidentifier] NOT NULL,
	[NomeEntrevistado] [nvarchar](100) NOT NULL,
	[NomeEntrevistador] [nvarchar](100) NOT NULL,
	[DataEntrevista] [datetime2](7) NOT NULL,
	[TipoEntrada] [int] NOT NULL,
	[TamanhoKloc] [decimal](10, 2) NOT NULL,
	[SomaScaleFactors] [decimal](10, 2) NOT NULL,
	[ProdutoEffortMultipliers] [decimal](10, 3) NOT NULL,
	[EsforcoPM] [decimal](10, 2) NOT NULL,
	[PrazoMeses] [decimal](10, 2) NOT NULL,
	[Linguagem] [nvarchar](100) NULL,
	[TotalCFP] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FatoresConversao]

-- %%
/****** Object:  Table [dbo].[FatoresConversao]    Script Date: 11/08/2025 20:06:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FatoresConversao](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TipoEntrada] [nvarchar](50) NOT NULL,
	[Contexto] [nvarchar](50) NOT NULL,
	[Nivel] [nvarchar](50) NOT NULL,
	[FatorConversao] [float] NOT NULL,
	[NomeCompleto] [varchar](150) NULL,
	[Descricao] [varchar](500) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Funcionalidades]

-- %%
/****** Object:  Table [dbo].[Funcionalidades]    Script Date: 11/08/2025 20:06:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Funcionalidades](
	[Id] [uniqueidentifier] NOT NULL,
	[EntrevistaId] [uniqueidentifier] NOT NULL,
	[Nome] [nvarchar](200) NOT NULL,
	[Template] [nvarchar](20) NULL,
	[Observacoes] [nvarchar](1000) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MedicoesCosmic]

-- %%
/****** Object:  Table [dbo].[MedicoesCosmic]    Script Date: 11/08/2025 20:06:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MedicoesCosmic](
	[Id] [uniqueidentifier] NOT NULL,
	[FuncionalidadeId] [uniqueidentifier] NOT NULL,
	[EntryE] [int] NOT NULL,
	[ExitX] [int] NOT NULL,
	[ReadR] [int] NOT NULL,
	[WriteW] [int] NOT NULL,
	[CFP]  AS ((([EntryE]+[ExitX])+[ReadR])+[WriteW]) PERSISTED,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosCocomo]

-- %%
/****** Object:  Table [dbo].[ParametrosCocomo]    Script Date: 11/08/2025 20:06:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosCocomo](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[A] [decimal](8, 4) NOT NULL,
	[B] [decimal](8, 4) NOT NULL,
	[C] [decimal](8, 4) NOT NULL,
	[D] [decimal](8, 4) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ScaleFactors]

-- %%
/****** Object:  Table [dbo].[ScaleFactors]    Script Date: 11/08/2025 20:06:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ScaleFactors](
	[Id] [uniqueidentifier] NOT NULL,
	[EntrevistaId] [uniqueidentifier] NOT NULL,
	[Nome] [nvarchar](50) NOT NULL,
	[Nivel] [nvarchar](50) NOT NULL,
	[Valor] [decimal](5, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_Entrevistas_TotalCFP]

-- %%
ALTER TABLE [dbo].[Entrevistas] ADD  CONSTRAINT [DF_Entrevistas_TotalCFP]  DEFAULT ((0)) FOR [TotalCFP]
GO

-- %% [markdown]
-- # [DF__Funcionalida__Id__44FF419A]

-- %%
ALTER TABLE [dbo].[Funcionalidades] ADD  DEFAULT (newid()) FOR [Id]
GO

-- %% [markdown]
-- # [DF__MedicoesCosm__Id__48CFD27E]

-- %%
ALTER TABLE [dbo].[MedicoesCosmic] ADD  DEFAULT (newid()) FOR [Id]
GO

-- %% [markdown]
-- # [DF__MedicoesC__Entry__49C3F6B7]

-- %%
ALTER TABLE [dbo].[MedicoesCosmic] ADD  DEFAULT ((0)) FOR [EntryE]
GO

-- %% [markdown]
-- # [DF__MedicoesC__ExitX__4AB81AF0]

-- %%
ALTER TABLE [dbo].[MedicoesCosmic] ADD  DEFAULT ((0)) FOR [ExitX]
GO

-- %% [markdown]
-- # [DF__MedicoesC__ReadR__4BAC3F29]

-- %%
ALTER TABLE [dbo].[MedicoesCosmic] ADD  DEFAULT ((0)) FOR [ReadR]
GO

-- %% [markdown]
-- # [DF__MedicoesC__Write__4CA06362]

-- %%
ALTER TABLE [dbo].[MedicoesCosmic] ADD  DEFAULT ((0)) FOR [WriteW]
GO

-- %% [markdown]
-- # [FK__EffortMul__Entre__3C69FB99]

-- %%
ALTER TABLE [dbo].[EffortMultipliers]  WITH CHECK ADD FOREIGN KEY([EntrevistaId])
REFERENCES [dbo].[Entrevistas] ([Id])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK_Func_Entrevistas]

-- %%
ALTER TABLE [dbo].[Funcionalidades]  WITH CHECK ADD  CONSTRAINT [FK_Func_Entrevistas] FOREIGN KEY([EntrevistaId])
REFERENCES [dbo].[Entrevistas] ([Id])
GO
ALTER TABLE [dbo].[Funcionalidades] CHECK CONSTRAINT [FK_Func_Entrevistas]
GO

-- %% [markdown]
-- # [FK_MedCos_Func]

-- %%
ALTER TABLE [dbo].[MedicoesCosmic]  WITH CHECK ADD  CONSTRAINT [FK_MedCos_Func] FOREIGN KEY([FuncionalidadeId])
REFERENCES [dbo].[Funcionalidades] ([Id])
GO
ALTER TABLE [dbo].[MedicoesCosmic] CHECK CONSTRAINT [FK_MedCos_Func]
GO

-- %% [markdown]
-- # [FK__ScaleFact__Entre__398D8EEE]

-- %%
ALTER TABLE [dbo].[ScaleFactors]  WITH CHECK ADD FOREIGN KEY([EntrevistaId])
REFERENCES [dbo].[Entrevistas] ([Id])
ON DELETE CASCADE
GO
